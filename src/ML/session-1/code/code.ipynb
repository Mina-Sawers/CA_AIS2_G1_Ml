# %%
x = 10
print(type(x))
x=13.4
print(type(x))
x=100
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
df = pd.read_csv('Titanic.csv')
x = df.drop('Survived', axis=1)
y = df['Survived']
num_cols = x.select_dtypes('number').columns
scaler = MinMaxScaler()
scaler.fit(x[num_cols])
x[num_cols] = scaler.transform(x[num_cols])
scaler.fit_transform
x
# Out:
#      PassengerId  Pclass  ... Cabin Embarked
# 0       0.000000     1.0  ...   NaN        S
# 1       0.001124     0.0  ...   C85        C
# 2       0.002247     1.0  ...   NaN        S
# 3       0.003371     0.0  ...  C123        S
# 4       0.004494     1.0  ...   NaN        S
# ..           ...     ...  ...   ...      ...
# 886     0.995506     0.5  ...   NaN        S
# 887     0.996629     0.0  ...   B42        S
# 888     0.997753     1.0  ...   NaN        S
# 889     0.998876     0.0  ...  C148        C
# 890     1.000000     1.0  ...   NaN        Q
#
# [891 rows x 11 columns]

# %%
from category_encoders import OneHotEncoder
df = pd.read_csv('Titanic.csv')
df = df.dropna(subset=['Embarked'])
# print(df['Embarked'].value_counts())
str_cols = ['Embarked']
encoder = OneHotEncoder(cols = str_cols,drop_invariant=True)
df = encoder.fit_transform(df)
print(df.head())
df.to_csv('Titanic_preprocessed.csv', index=False)
# Out:
#    PassengerId  Survived  Pclass  ... Embarked_1 Embarked_2  Embarked_3
# 0            1         0       3  ...          1          0           0
# 1            2         1       1  ...          0          1           0
# 2            3         1       3  ...          1          0           0
# 3            4         1       1  ...          1          0           0
# 4            5         0       3  ...          1          0           0
#
# [5 rows x 14 columns]
