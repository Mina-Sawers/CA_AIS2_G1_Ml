# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,root_mean_squared_error
import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv('salary_data.csv')

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.figure(figsize=(3,3))
sns.pairplot(data,x_vars=['YearsExperience'],y_vars=['Salary'],size=3,kind="scatter")
plt.xlabel('years')
plt.ylabel('salary')
plt.title('salary prediction')
# Out:
# Text(0.5, 1.0, 'salary prediction')

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,1]

x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
x_train
# Out:
#     YearsExperience
# 28             10.3
# 24              8.7
# 12              4.0
# 0               1.1
# 4               2.2
# 16              5.1
# 5               2.9
# 13              4.1
# 11              4.0
# 22              7.9
# 1               1.3
# 2               1.5
# 25              9.0
# 3               2.0
# 21              7.1
# 26              9.5
# 18              5.9
# 29             10.5
# 20              6.8
# 7               3.2
# 10              3.9
# 14              4.5
# 19              6.0
# 6               3.0

# %%
y_train
# Out:
# 28    122391.0
# 24    109431.0
# 12     56957.0
# 0      39343.0
# 4      39891.0
# 16     66029.0
# 5      56642.0
# 13     57081.0
# 11     55794.0
# 22    101302.0
# 1      46205.0
# 2      37731.0
# 25    105582.0
# 3      43525.0
# 21     98273.0
# 26    116969.0
# 18     81363.0
# 29    121872.0
# 20     91738.0
# 7      54445.0
# 10     63218.0
# 14     61111.0
# 19     93940.0
# 6      60150.0
# Name: Salary, dtype: float64

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train,y_train)
print(lin_reg.coef_)
print(lin_reg.intercept_)
y_hat_train = lin_reg.predict(x_train)
# Out:
# [9423.81532303]
# 25321.583011776813

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,y_hat_train,color='blue')
plt.title("Salary vs Experience")
plt.xlabel('years')
plt.ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %%
y_hat_test = lin_reg.predict(x_test)
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_hat_test,color='blue')
plt.title('Salary vs Experience')
plt.xlabel('years')
plt.ylabel('salary')
plt.show()

# %%
#calculation mse
mse = mean_squared_error(y_test,y_hat_test)
print(mse)
rmse = root_mean_squared_error(y_test,y_hat_test)
print(rmse)
#r2 score
# Out:
# 49830096.85590839
# 7059.04362190151

# %%
mse = mean_squared_error(x_train,y_train)
print(mse)
rmse = root_mean_squared_error(x_train,y_train)
print(rmse)
r2 = r2_score(y_train,y_hat_train)
print(r2)
# Out:
# 6270153517.611249
# 79184.30095423745
# 0.9645401573418146

# %%
w = lin_reg.coef_
b = lin_reg.intercept_
print(w,b)
print(type(w))
# y_pred = w*x+b

input_x = int(input("enter years of experience: "))
y_pred = w * input_x + b
print(y_pred)
# Out:
# [9423.81532303] 25321.583011776813
# <class 'numpy.ndarray'>
# [110135.92091906]

# %%
# !pip install tkintertable
# Out:
# Collecting tkintertable
#   Downloading tkintertable-1.3.3.tar.gz (58 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting future (from tkintertable)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Building wheels for collected packages: tkintertable
#   Building wheel for tkintertable (pyproject.toml): started
#   Building wheel for tkintertable (pyproject.toml): finished with status 'done'
#   Created wheel for tkintertable: filename=tkintertable-1.3.3-py3-none-any.whl size=66249 sha256=967551b3dbef474c0f1cf0bd031134d6d757a06334be60239d24f5d28473b843
#   Stored in directory: c:\users\clown\appdata\local\pip\cache\wheels\93\b5\2d\e0c1d9fad21eeab6171702bc918627821cb2c46aecc7e69bb9
# Successfully built tkintertable
# Installing collected packages: future, tkintertable
#
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    ---------------------------------------- 0/2 [future]
#    -------------------- ------------------- 1/2 [tkintertable]
#    -------------------- ------------------- 1/2 [tkintertable]
#    -------------------- ------------------- 1/2 [tkintertable]
#    ---------------------------------------- 2/2 [tkintertable]
#
# Successfully installed future-1.0.0 tkintertable-1.3.3
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tkinter as tk
import numpy as np

class SalaryPredictionApp:
    def __init__(self,root)->None:
        self.root = root
        self.root.title("Depi for Machine Learning")
        self.root.geometry("500x400")
        self.create_widgets()
    


if __name__ == "__main__":
    root = tk.Tk()
    app = SalaryPredictionApp(root)
    root.mainloop()
