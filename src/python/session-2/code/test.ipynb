# %%
t = 1,2,3
list1 = list(t)
print(type(list1))
print(list1)
# Out:
# <class 'list'>
# [1, 2, 3]

# %%
set1 = set()
set1.add(5)
set1.add(1)
set1.add(7)
set1.add(2)
print(set1)
# Out:
# {1, 2, 5, 7}

# %%
set2 = {-5,7,1,2}
print(set2)
# Out:
# {1, 2, -5, 7}

# %%
words = {"depi","python","python"}
unique_words = list(words)
print(unique_words)
# Out:
# ['depi', 'python']
