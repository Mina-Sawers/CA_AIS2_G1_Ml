# %%
x=7
print(x)
# Out:
# 7

# %%
print("Mina",20)
# Out:
# Mina 20

# %%
y=20
hex(id(y))
# Out:
# '0x7ff856fa4c18'

# %%
x=30 #this variable is integer
# print(x)
# Out:
# 30

# %%
y=40
z=550
''' multiline
comment


'''

"""
second
multiline
comment
"""
# Out:
# ''

# %%
a = '''
I
will
test
'''
print(a)
# Out:
# I
# will
# test

# %%
print("My name is","mina","age =",50)
name = "Hazem"
age = 40
print("My name is {0} and my age is {1}".format(name,age))
print(f"My name is {"Ali"} and my is {60}")
# Out:
# My name is mina age = 50
# My name is Hazem and my age is 40
# My name is Ali and my is 60

# %%
def info():
    return f"My name is {"Ali"} and my is {60}"

# %%
name = "Mina"
age = 25
course = "Python"
print(f"My name is {name} and my age is {age} and I study {course}")
# Out:
# My name is Mina and my age is 25 and I study Python

# %%
x=True
print(type(x))
# Out:
# <class 'bool'>

# %%
lst_1 = [1,2,3,4,5]
print(type(lst_1))
lst_1.append('ahmed')
print(lst_1)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5, 'ahmed']

# %%
tup_1 = (1,2,3,4,5)
print(type(tup_1))
tup_1 = (1)
print(type(tup_1))
# Out:
# <class 'tuple'>
# <class 'int'>

# %%
print(type(tup_1))
# Out:
# <class 'list'>

# %%
list1 = [1,2,3,4,5]
tup = tuple(list1)
print(type(tup))
# Out:
# <class 'tuple'>

# %%
set_1 = {1,2,3}
print(type(set_1))
# Out:
# <class 'set'>

# %%
dict_1 = {"k1":1,"k2":2}
print(type(dict_1))
print(dict_1.items())
print(dict_1.keys())
# Out:
# <class 'dict'>
# dict_items([('k1', 1), ('k2', 2)])
# dict_keys(['k1', 'k2'])

# %%
x = "depi for machine learning"
type(x)
print(x[0])
print(x[-1])
print(x[5:8:1])
print(x[::-1])
print(x[::])
# Out:
# d
# g
# for
# gninrael enihcam rof iped
# depi for machine learning

# %%
name = "Depi for machine learning for everyone"
capital = name.upper()
print(capital)
lower = name.lower()
print(lower)
#print(name.lower())
# Out:
# DEPI FOR MACHINE LEARNING FOR EVERYONE
# depi for machine learning for everyone

# %%
name = "depi learning depi"
name.replace("depi","machine")
# Out:
# 'machine learning machine'

# %%
name = "depi for ai "
name.capitalize()
# Out:
# 'Depi for ai '

# %%
name = "depi for everyone"
name.title()
# Out:
# 'Depi For Everyone'

# %%
name = "depi for machine learning and depi for genai"
name.count("depi")
# Out:
# 2

# %%
name = "depi for machine learning and depi for genai"
name.split(" ")
x=name.split(" ")

# %%
new_x = ' '.join(x)

# %%
print(new_x)
# Out:
# depi for machine learning and depi for genai

# %%
name = "depi for machine learning and depi for genai"
name.startswith("depi")
name.endswith("depi")
# Out:
# False

# %%
print("hello \n world for\b \t \"students\" in depi")
# Out:
# hello
#  world fo 	 "students" in depi
